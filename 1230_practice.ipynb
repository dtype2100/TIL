# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/TIL/blob/master/1230_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
resp = requests.get("https://scrapying-study.firebaseapp.com/04/")
resp.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <meta charset="utf-8">\n    <script src="https://code.jquery.com/jquery-3.4.1.js" integrity="sha256-WpOohJOqMqqyKL9FccASB9O0KwACQJpFTUBLTYOVvVU=" crossorigin="anonymous"></script>\n    <script>   \n    $(function() {\n        // Document is ready\n\n        $.get("https://jsonplaceholder.typicode.com/posts",function(jqXHR) {\n            for (let i = 0 ; i < jqXHR.length ; i++) {\n                $("#post").append("<div style=\'margin-top:20px;font-size:14px;font-weight:bold;\'>" + jqXHR[i].title + "</div><div stlye=\'margin-top:5px;font-size:12px;\'>" + jqXHR[i].body + "</div>");\n            }\n        },\'json\' /* xml, text, script, html */)\n        .done(function(jqXHR) {\n            // alert("second success" );\n        })\n        .fail(function(jqXHR) {\n            // alert("error" );\n        })\n        .always(function(jqXHR) {\n            // alert("finished" );\n        });        \n        \n    });\n    </script>\n    <title>Dem
# ...

# %%
resp.status_code
# Out:
# 200

# %%
resp = requests.get("https://jsonplaceholder.typicode.com/posts")
resp.text
# Out:
# '[\n  {\n    "userId": 1,\n    "id": 1,\n    "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",\n    "body": "quia et suscipit\\nsuscipit recusandae consequuntur expedita et cum\\nreprehenderit molestiae ut ut quas totam\\nnostrum rerum est autem sunt rem eveniet architecto"\n  },\n  {\n    "userId": 1,\n    "id": 2,\n    "title": "qui est esse",\n    "body": "est rerum tempore vitae\\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\\nqui aperiam non debitis possimus qui neque nisi nulla"\n  },\n  {\n    "userId": 1,\n    "id": 3,\n    "title": "ea molestias quasi exercitationem repellat qui ipsa sit aut",\n    "body": "et iusto sed quo iure\\nvoluptatem occaecati omnis eligendi aut ad\\nvoluptatem doloribus vel accusantium quis pariatur\\nmolestiae porro eius odio et labore et velit aut"\n  },\n  {\n    "userId": 1,\n    "id": 4,\n    "title": "eum et est occaecati"
# ...

# %%
import json

result_dic = json.loads(resp.text)
print(type(result_dic))
# Out:
# <class 'list'>

# %%
result_dic[0]
# Out:
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
with open("data.json", "w", encoding="utf-8") as file:
    json.dump(result_dic, file)

# %%
with open("data.json", "r", encoding="utf-8") as file:
    result = json.load(file)
    
print(result)
# Out:
# [{'userId': 1, 'id': 1, 'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit', 'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}, {'userId': 1, 'id': 2, 'title': 'qui est esse', 'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'}, {'userId': 1, 'id': 3, 'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut', 'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'}, {'userId': 1, 'id': 4, 'title': 'eum et est occaecati', 'body': 'ullam et saepe reiciendis voluptatem adipisci\nsit amet autem assumenda provident rerum culpa\nquis hic
# ...

# %%
result_dic
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10488/1548513962.py in <module>
# ----> 1 result_dic
#
# NameError: name 'result_dic' is not defined

# %%
resp = requests.get("https://jsonplaceholder.typicode.com/photos")
result = json.loads(resp.text)

# %%
result
# Out:
# [{'albumId': 1,
#   'id': 1,
#   'title': 'accusamus beatae ad facilis cum similique qui sunt',
#   'url': 'https://via.placeholder.com/600/92c952',
#   'thumbnailUrl': 'https://via.placeholder.com/150/92c952'},
#  {'albumId': 1,
#   'id': 2,
#   'title': 'reprehenderit est deserunt velit ipsam',
#   'url': 'https://via.placeholder.com/600/771796',
#   'thumbnailUrl': 'https://via.placeholder.com/150/771796'},
#  {'albumId': 1,
#   'id': 3,
#   'title': 'officia porro iure quia iusto qui ipsa ut modi',
#   'url': 'https://via.placeholder.com/600/24f355',
#   'thumbnailUrl': 'https://via.placeholder.com/150/24f355'},
#  {'albumId': 1,
#   'id': 4,
#   'title': 'culpa odio esse rerum omnis laboriosam voluptate repudiandae',
#   'url': 'https://via.placeholder.com/600/d32776',
#   'thumbnailUrl': 'https://via.placeholder.com/150/d32776'},
#  {'albumId': 1,
#   'id': 5,
#   'title': 'natus nisi omnis corporis facere molestiae rerum in',
# ...

# %%
with open("sample.json", "w", encoding="utf-8") as file:
    json.dump(result, file)

# %%
for more in result['moreList']:
    if more['targetCode'] == '공모전':
        titles.append(more['title'])
    
titles
# Out:
# ['스마트축사 데이터 활용 대회',
#  '원자력 글로벌 아이디어 제안전',
#  'VIDEO ENTERTAINER CONTEST',
#  '‘현대 블루 프라이즈 디자인 2021’ 첫 번째 수상자 심소미 큐레이터',
#  "세븐일레븐, 자체 채식 전문 브랜드 '그레인그레잇' 론칭",
#  "일룸 디지털 VR 쇼룸, '웹어워드코리아 2021’ 대상 수상",
#  '스마트축사 데이터 활용 대회',
#  '원자력 글로벌 아이디어 제안전',
#  'VIDEO ENTERTAINER CONTEST']

# %%
title = []
magazineOffset = 0
contestOffset = 0

for i in range(10):
    resp = requests.get(f"https://www.jungle.co.kr/recent.json?magazineOffset={magazineOffset}&contestOffset={contestOffset}&exhibitOffset=0&galleryOffset=0")
    
    result = json.loads(resp.text)
    
    for more in result['moreList']:
        if more['targetCode'] == '공모전':
            titles.append(more['title'])
    
    magazineOffset = result["magazineOffset"]
    contestOffset = result["contestOffset"]
            
titles
# Out:
# ['[노트하우 서포터즈]노트하우 갓-생즈 1기 모집',
#  '2021 소상공인 온라인교육 영상 콘텐츠 공모전',
#  '제1회 전기안전 정책 경진대회',
#  '크레모아 아웃트로 디자인 공모전',
#  '[한국에너지공단] 탄소중립을 위한 20도 챌린지',
#  '마인드인성교육원이 주최하는 "제1회 초등부 영어말하기대회"',
#  '제1회 콘텐츠 기획 아이디어 글로벌 공모전',
#  '[Hustar] 대구혁신아카데미 5기 교육생 모집',
#  '중소벤처24 지능형 분석 서비스 모델 발굴 공모전(~1/28, 접수기간 연장)',
#  '[페이스북 유니버시티] ✨페이스북 마케팅 대외활동 출범!✨(~12/26) ',
#  'SS쿠폰 마케팅 서포터즈 1기 모집',
#  '문화재 재난안전 공모전(그림엽서, 영상)',
#  '제2회 연구개발특구 인공지능 경진대회 AI SPARK 챌린지',
#  "SS쿠폰 서포터즈 'SS프렌즈' 1기 모집",
#  '스마트축사 데이터 활용 대회',
#  '원자력 글로벌 아이디어 제안전',
#  'VIDEO ENTERTAINER CONTEST',
#  '[노트하우 서포터즈]노트하우 갓-생즈 1기 모집',
#  '2021 소상공인 온라인교육 영상 콘텐츠 공모전',
#  '제1회 전기안전 정책 경진대회',
#  '크레모아 아웃트로 디자인 공모전',
#  '[한국에너지공단] 탄소중립을 위한 20도 챌린지',
#  '마인드인성교육원이 주최하는 "제1회 초등부 영어말하기대회"',
#  '제1회 콘텐츠 기획 아이디어 글로벌 공모전',
#  '[Hustar] 대구혁신아카데미 5기 교육생 모집',
#  '중소벤처24 지능형 분석 서비스 모델 발굴 공모전(~1/28, 접수기간 연장)',
#  '[페이스북 유니버시티] ✨페이스북 마케팅 대외활동 출범!✨(~12/26) ',
#  'SS쿠폰 마케팅 서포터즈 1기 모집',
#  '문화재 재난안전 공모전(그림엽서, 영상)']

# %%
resp = requests.get('https://www.youtube.com/watch?v=8AUXRGIjUXk')
html = BeautifulSoup(resp.text, "html.parser")
html.select("ytd-comments")
# Out:
# []

# %%
print(html.find("comments"))
# Out:
# None

# %%
url = "https://comic.naver.com/webtoon/weekdayList?week=fri"

# %%
resp = requests.get(url)
html = BeautifulSoup(resp.text, "html.parser")
lis = html.select(".img_list > li")
len(lis)
# Out:
# 77

# %%
for li in lis:
    print("제목 : {}".format(li.select_one("dt").text.strip()))
    print("작가 : {}".format(li.select_one("dd.desc").text.strip()))
    print("평점 : {}".format(li.select_one("div.rating_type strong").text.strip()))
    print()
# Out:
# 제목 : 쇼미더럭키짱!
# 작가 : 박태준 / 김성모
# 평점 : 9.03
#
# 제목 : 외모지상주의
# 작가 : 박태준
# 평점 : 9.46
#
# 제목 : 나 혼자 만렙...
# 작가 : 메슬로우,WAN.Z / 스...
# 평점 : 9.80
#
# 제목 : 데드퀸
# 작가 : 김규삼
# 평점 : 9.96
#
# 제목 : 내과 박원장
# 작가 : 장봉수
# 평점 : 9.91
#
# 제목 : 재혼 황후
# 작가 : 알파타르트,히어리 / 숨풀
# 평점 : 9.97
#
# 제목 : 광마회귀
# 작가 : 유진성, JP / 이히
# 평점 : 9.95
#
# 제목 : 1초
# 작가 : 시니 / 광운
# 평점 : 9.97
#
# 제목 : 개를 낳았다
# 작가 : 이선
# 평점 : 9.93
#
# 제목 : 죽지 않으려면
# 작가 : 파래 / 임진국
# 평점 : 9.93
#
# 제목 : 상위1%
# 작가 : 미티 / 웅비
# 평점 : 9.19
#
# 제목 : 삼국지톡
# 작가 : 무적핑크 / 이리
# 평점 : 9.91
#
# 제목 : 2022 서브...
# 작가 : 웹툰작가
# 평점 : 9.96
#
# 제목 : 소극적 인간
# 작가 : 다쓴총
# 평점 : 9.87
#
# 제목 : 낙향문사전
# 작가 : 최현우,바킹독 / 팀 페가...
# 평점 : 9.73
#
# 제목 : [사전이벤트]...
# 작가 : 네이버웹툰
# 평점 : 2.63
#
# 제목 : 서울역 드루이드
# 작가 : 진설우, 문성호 / 활성곰
# 평점 : 9.68
#
# 제목 : 세기말 풋사과...
# 작가 : 순끼
# 평점 : 9.98
#
# 제목 : 푸쉬오프
# 작가 : 허5파6
# 평점 : 9.98
#
# 제목 : 더 게이머
# 작가 : 성상영 / 상아
# 평점 : 8.55
#
# 제목 : 상남자
# 작가 : 도가도
# 평점 : 9.94
#
# 제목 : 뫼신 사냥꾼
# 작가 : 윤현승, 승림 / 방승현
# 평점 : 9.92
#
# 제목 : 걸어서 30분
# 작가 : 이온도
# 평점 : 9.97
#
# ...

# %%
url = "https://finance.naver.com/sise/sise_quant.nhn"
resp = requests.get(url)
html = BeautifulSoup(resp.text, "html.parser")
trs = html.select(".type_2 tr")
len(trs)
# Out:
# 162

# %%
for tr in trs:
    no = tr.select_one(".no")
    if no:
        no = no.text.strip()
        item = tr.select_one(".tltle").text.strip()
        curr = tr.select_one(".number").text.strip()
        print(f"{no}\t{item}\t{curr}")
# Out:
# 1	KODEX 200선물인버스2X	2,155
# 2	써니전자	4,625
# 3	이엔플러스	4,890
# 4	KODEX 코스닥150선물인버스	4,030
# 5	까뮤이앤씨	2,765
# 6	쌍방울	807
# 7	KODEX 인버스	4,005
# 8	삼부토건	2,385
# 9	KODEX 레버리지	23,895
# 10	삼성전자	78,300
# 11	신원	2,895
# 12	KODEX 코스닥150 레버리지	16,465
# 13	삼성 인버스 2X WTI원유 선물 ETN	350
# 14	이수페타시스	7,460
# 15	KEC	3,705
# 16	이아이디	302
# 17	SG세계물산	685
# 18	SK하이닉스	130,000
# 19	일성건설	6,200
# 20	주연테크	1,315
# 21	대한전선	1,785
# 22	LG디스플레이	24,500
# 23	TIGER 글로벌메타버스액티브	10,270
# 24	TCC스틸	9,660
# 25	KODEX 코스닥 150	15,080
# 26	체시스	1,275
# 27	퍼스텍	2,795
# 28	동방아그로	7,430
# 29	신성통상	3,375
# 30	넥스트사이언스	21,950
# 31	서울식품	330
# 32	한화투자증권	6,310
# 33	진원생명과학	16,250
# 34	대덕전자	24,850
# 35	SK스퀘어	66,600
# 36	두산중공업	20,350
# 37	SK증권	1,010
# 38	플레이그램	2,600
# 39	TIGER 200선물인버스2X	2,255
# 40	TIGER 차이나전기차SOLACTIVE	17,750
# 41	한화생명	2,950
# 42	영화금속	1,625
# 43	삼성중공업	5,700
# 44	NPC	10,200
# 45	웰바이오텍	1,790
# 46	에이프로젠 MED	1,675
# 47	KODEX 200	39,850
# 48	조일알미늄	1,955
# 49	삼성 레버리지 WTI원유 선물 ETN	1,130
# 50	제이준코스메틱	1,020
# 51	이월드	2,700
# ...

# %%
url = "https://finance.naver.com/sise/sise_quant.nhn"
resp = requests.get(url)
html = BeautifulSoup(resp.text, "html.parser")
trs = html.select(".type_2 tr")

for tr in trs:
    no = tr.select_one(".no")
    if no:
        updown_tr = tr.select(".number")
        ratio = updown_tr[1].select_one(".red02")
        if ratio:
            no = no.text.strip()
            item = tr.select_one(".tltle").text.strip()
            curr = tr.select_one(".number").text.strip()
            ratio_text = ratio.text.strip()
            print(f"{no}\t{item}\t{curr}\t{ratio_text}")
# Out:
# 1	KODEX 200선물인버스2X	2,155	25
# 2	써니전자	4,590	465
# 3	이엔플러스	4,850	255
# 5	까뮤이앤씨	2,770	60
# 6	쌍방울	811	24
# 7	KODEX 인버스	4,000	20
# 8	삼부토건	2,385	185
# 11	신원	2,895	25
# 12	KODEX 코스닥150 레버리지	16,575	65
# 14	이수페타시스	7,410	540
# 17	SG세계물산	683	13
# 18	SK하이닉스	130,500	3,500
# 19	일성건설	6,230	290
# 20	주연테크	1,300	50
# 21	LG디스플레이	24,600	300
# 24	TCC스틸	9,760	870
# 25	KODEX 코스닥 150	15,125	30
# 26	체시스	1,270	65
# 28	동방아그로	7,410	290
# 29	신성통상	3,385	155
# 30	넥스트사이언스	21,950	1,200
# 31	서울식품	330	3
# 33	진원생명과학	16,200	550
# 34	대덕전자	24,950	950
# 35	SK스퀘어	66,800	2,300
# 38	플레이그램	2,605	70
# 39	TIGER 200선물인버스2X	2,245	25
# 42	영화금속	1,625	25
# 47	에이프로젠 MED	1,675	30
# 49	삼성 레버리지 WTI원유 선물 ETN	1,125	15
# 55	드림텍	12,050	800
# 56	KODEX K-메타버스액티브	13,335	15
# 57	신성이엔지	2,150	55
# 58	파미셀	13,150	200
# 59	범양건영	6,460	370
# 61	이스타코	3,070	215
# 62	갤럭시아에스엠	3,045	65
# 63	노루페인트	14,700	100
# 64	한국토지신탁	2,630	40
# 65	IHQ	1,480	30
# 68	신한 레버리지 WTI원유 선물 ETN(H)	910	15
# 71	일동제약	30,900	600
# 74	KOSEF 통안채1년	101,120	5
# 77	대유에이텍	1,285	5
# ...

# %%
for tr in trs:
    imgs = tr.select_one('img[alt]')
    if imgs and imgs.attrs["alt"] == "상승":
        print(tr.select_one(".tltle").text.strip())
# Out:
# KODEX 200선물인버스2X
# 써니전자
# 이엔플러스
# 까뮤이앤씨
# 쌍방울
# KODEX 인버스
# 삼부토건
# 신원
# KODEX 코스닥150 레버리지
# 이수페타시스
# SG세계물산
# SK하이닉스
# 일성건설
# 주연테크
# LG디스플레이
# TCC스틸
# KODEX 코스닥 150
# 체시스
# 동방아그로
# 신성통상
# 넥스트사이언스
# 서울식품
# 진원생명과학
# 대덕전자
# SK스퀘어
# 플레이그램
# TIGER 200선물인버스2X
# 영화금속
# 에이프로젠 MED
# 삼성 레버리지 WTI원유 선물 ETN
# 드림텍
# KODEX K-메타버스액티브
# 신성이엔지
# 파미셀
# 범양건영
# 이스타코
# 갤럭시아에스엠
# 노루페인트
# 한국토지신탁
# IHQ
# 신한 레버리지 WTI원유 선물 ETN(H)
# 일동제약
# KOSEF 통안채1년
# 대유에이텍
# KC그린홀딩스
# 한창
# KBSTAR 단기통안채
# 대유플러스
# 일신석재
# 이구산업
# 후성
# 금호에이치티
# 한국전력
# 코리아써키트
# 유니퀘스트
# 동방
# 현대두산인프라코어

# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys



options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("--no-sandbox")
options.add_argument("disable-dev-shm-usage")

driver = webdriver.Chrome('./chromedriver', chrome_options=options)
driver.get('https://finance.naver.com/sise/sise_quant.nhn')
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/899967627.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver', chrome_options=options)
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/899967627.py:11: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('./chromedriver', chrome_options=options)

# %%
elem = driver.find_element_by_css_selector("#contentarea > div.box_type_l > table > tbody > tr:nth-child(3) > td:nth-child(2) > a")
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/2386203782.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_css_selector("#contentarea > div.box_type_l > table > tbody > tr:nth-child(3) > td:nth-child(2) > a")

# %%
type(elem)
# Out:
# selenium.webdriver.remote.webelement.WebElement

# %%
elem.text
# Out:
# 'KODEX 200선물인버스2X'

# %%
trs = driver.find_elements_by_css_selector(".type_2 tr")
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/499438769.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   trs = driver.find_elements_by_css_selector(".type_2 tr")

# %%
print(type(driver))
print(type(trs[0]))
# Out:
# <class 'selenium.webdriver.chrome.webdriver.WebDriver'>
# <class 'selenium.webdriver.remote.webelement.WebElement'>

# %%
# for tr in trs:
#     no = tr.select_one(".no")
#     if no:
#         no = no.text.strip()
#         item = tr.select_one(".tltle").text.strip()
#         curr = tr.select_one(".number").text.strip()
#         print(f"{no}\t{item}\t{curr}")

for tr in trs:
    no = tr.find_elements_by_css_selector(".no")
    if len(no) > 0:
        no = no[0].text.strip()
        item = tr.find_elements_by_css_selector(".tltle")[0].text.strip()
        curr = tr.find_elements_by_css_selector(".number")[0].text.strip()
        print(f"{no}\t{item}\t{curr}")
# Out:
# 1	KODEX 200선물인버스2X	2,155
# 2	써니전자	4,650
# 3	이엔플러스	4,780
# 4	KODEX 코스닥150선물인버스	4,025
# 5	까뮤이앤씨	2,815
# 6	쌍방울	808
# 7	KODEX 인버스	4,000
# 8	KODEX 레버리지	23,865
# 9	삼부토건	2,360
# 10	삼성전자	78,500
# 11	신원	2,910
# 12	KODEX 코스닥150 레버리지	16,510
# 13	삼성 인버스 2X WTI원유 선물 ETN	355
# 14	이수페타시스	7,290
# 15	KEC	3,705
# 16	LG디스플레이	24,550
# 17	이아이디	302
# 18	대한전선	1,780
# 19	SK하이닉스	130,500
# 20	일성건설	6,260
# 21	KODEX 코스닥 150	15,115
# 22	SG세계물산	684
# 23	주연테크	1,290
# 24	TIGER 글로벌메타버스액티브	10,300
# 25	일동제약	32,900
# 26	퍼스텍	2,780
# 27	이스타코	3,080
# 28	TCC스틸	9,660
# 29	한화투자증권	6,390
# 30	신성통상	3,400
# 31	서울식품	330
# 32	체시스	1,255
# 33	두산중공업	20,450
# 34	KODEX 200	39,850
# 35	NPC	10,450
# 36	넥스트사이언스	21,800
# 37	CJ씨푸드	3,825
# 38	SK증권	1,005
# 39	한화생명	2,940
# 40	동방아그로	7,280
# 41	대덕전자	24,850
# 42	플레이그램	2,570
# 43	TIGER 차이나전기차SOLACTIVE	17,705
# 44	삼성중공업	5,680
# 45	SK스퀘어	66,300
# 46	에이프로젠 MED	1,680
# 47	KODEX 미국메타버스나스닥액티브	10,145
# 48	진원생명과학	16,250
# 49	TIGER 200선물인버스2X	2,250
# 50	노루페인트	14,950
# 51	신한 인버스 2X WTI원유 선물 ETN(H)	350
# ...

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get('https://www.jungle.co.kr')
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
driver.implicitly_wait(2)
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/1458008033.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')

# %%
import time

driver = webdriver.Chrome('./chromedriver')
driver.get('https://www.jungle.co.kr')
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
driver.implicitly_wait(2)

more_button = driver.find_element_by_css_selector('#existMore')
more_button.click()

time.sleep(1)

more_button = driver.find_element_by_css_selector('#existMore')
more_button.click()
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/1274039038.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/1274039038.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   more_button = driver.find_element_by_css_selector('#existMore')
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/1274039038.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   more_button = driver.find_element_by_css_selector('#existMore')

# %%
resp = requests.get('https://www.youtube.com/watch?v=8AUXRGIjUXk')
html = BeautifulSoup(resp.text, "html.parser")
print(html.select_one(".view-count"))
# Out:
# None

# %%
resp.text
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="ko-KR" system-icons typography typography-spacing><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><script nonce="wie8+kuHwPNHPVz8/aojNg">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20211221.00.00\');</script><script nonce="wie8+kuHwPNHPVz8/aojNg">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber
# ...

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get('https://www.youtube.com/watch?v=8AUXRGIjUXk')
driver.implicitly_wait(2)
print(driver.find_element_by_css_selector(".view-count").text)
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/242897835.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# 조회수 8,714회
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/242897835.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   print(driver.find_element_by_css_selector(".view-count").text)

# %%
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("--no-sandbox")
options.add_argument("disable-dev-shm-usage")

driver = webdriver.Chrome('./chromedriver', chrome_options=options)
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/167731398.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver', chrome_options=options)
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/167731398.py:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('./chromedriver', chrome_options=options)

# %%
driver.get('https://www.youtube.com/watch?v=8AUXRGIjUXk')
driver.implicitly_wait(1)
print(driver.find_element(By.CSS_SELECTOR, ".view-count").text)
# Out:
# 조회수 8,731회

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get("https://www.youtube.com/watch?v=W7edvITC9g4")
driver.implicitly_wait(5)


last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:
    # Scroll down 'til "next load".
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load everything thus far.
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height.
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
    
    #댓글 수집
    
    

# One last scroll just in case.
driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/1685403678.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10488/1685403678.py in <module>
#      17
#      18     # Calculate new scroll height and compare with last scroll height.
# ---> 19     new_height = driver.execute_script("return document.documentElement.scrollHeight")
#      20     if new_height == last_height:
#      21         break
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     876         command = Command.W3C_EXECUTE_SCRIPT
#     877
# --> 878         return self.execute(command, {
#     879             'script': script,
# ...

# %%
driver = webdriver.Chrome('./chromedriver')
driver.get('https://www.youtube.com/watch?v=W7edvITC9g4')
driver.implicitly_wait(1)
print(driver.find_element_by_css_selector(".view-count").text)
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/792659885.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# C:\Users\student\AppData\Local\Temp/ipykernel_10488/792659885.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   print(driver.find_element_by_css_selector(".view-count").text)
# 조회수 6,746,487회
