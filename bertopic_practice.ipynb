# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/TIL/blob/master/bertopic_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic[visualization]
# Out:
# ...
#      |████████████████████████████████| 58 kB 4.4 MB/s
# WARNING: bertopic 0.10.0 does not provide the extra 'visualization'
# ...
#      |████████████████████████████████| 79 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 88 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 3.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 4.0 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 43.5 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 36.0 MB/s
# ...
#      |████████████████████████████████| 636 kB 37.3 MB/s
# ...
#      |████████████████████████████████| 880 kB 46.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 47.2 MB/s
# ...

# %%
# !pip install bertopic

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 1006.00 KiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# ...
#      |████████████████████████████████| 19.4 MB 5.9 MB/s
# ...
#      |████████████████████████████████| 448 kB 39.3 MB/s
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-05-11 11:22:12--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c5:2ef4, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# ...

# %%
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from bertopic import BERTopic

# %%
from bertopic import BERTopic
import pandas as pd

# %%
df1 = pd.read_excel('')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6])

# %%
df.head(3)
# Out:
#    Unnamed: 0  Unnamed: 0.1         일자  \
# 0           0          3485 2021-01-04
# 1           1          3466 2021-01-05
# 2           2          3455 2021-01-05
#
#                                        제목  \
# 0    '11번가-아마존' '네이버쇼핑-CJ' 연합...판 키우는 강자들
# 1  [클릭 e종목] "네이버, 국내 외 실적 증익 구간 저가 매수 유효"
# 2    [OBS 비즈투데이] 법률구조공단 홈페이지, 네이버 인증 사용 外
#
#                                                  URL
# 0         http://www.sedaily.com/NewsView/22H4HCSLDI
# 1  https://www.asiae.co.kr/article/20210105071156...
# 2  http://www.obsnews.co.kr/news/articleView.html...

# %%
docs = df[['일자', '제목']]

# %%
docs = docs.loc[:430]

# %%
preprocessed_documents = []

for line in tqdm(docs):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
#   0%|          | 2/430 [00:00<00:00, 10951.19it/s]

# %%
preprocessed_documents
# Out:
# ['일자', '제목']

# %%
preprocessed_documents[:5]
# Out:
# ['일자', '제목']

# %%
print('총 문서의 수 :', len(preprocessed_documents))
# Out:
# 총 문서의 수 : 2

# %% [markdown]
# #Mecab과 SBERT를 이용한 Bertopic

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        sent = sent[:1000000]
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", \
                 vectorizer_model=vectorizer,
                 nr_topics=50,
                 top_n_words=10,
                 calculate_probabilities=True)

# %%
topics, probs = model.fit_transform(preprocessed_documents)
# Out:
# Downloading:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527 [00:00<?, ?B/s]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_distribution(probs[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i in range(0, 50):
  print(i,'번째 토픽 :', model.get_topic(i))
# Out:
# 0 번째 토픽 : [('cj', 0.27572705525036495), ('동맹', 0.10198256478000084), ('맞교환', 0.10114427093593638), ('콘텐츠', 0.07915905098107524), ('통운', 0.06944179130430539), ('대한', 0.06534795538491772), ('물류', 0.06388219402892856), ('물꼬', 0.06001697469982607), ('문화', 0.06001697469982607), ('주식', 0.05566030443486919)]
# 1 번째 토픽 : [('매출', 0.11755292645273833), ('시대', 0.07886739319695299), ('영업', 0.06783914991852173), ('연속', 0.04381395691786724), ('상보', 0.04270028853671519), ('실적', 0.03984799886133521), ('400', 0.03921686794465169), ('납부', 0.03921686794465169), ('전액', 0.03921686794465169), ('재단', 0.03921686794465169)]
# 2 번째 토픽 : [('52', 0.3671641666479996), ('신저', 0.18820844669575051), ('신고', 0.1507601773127238), ('경신', 0.11739791243384194), ('30', 0.09461083360378342), ('장중', 0.09316419207296031), ('특징', 0.06955591348214743), ('후끈', 0.060024439308964575), ('근무', 0.060024439308964575), ('..‘', 0.060024439308964575)]
# ...

# %%
model.get_topic_info()
# Out:
#     Topic  Count                 Name
# 0      -1    753    -1_네이버_카카오_투자_이해진
# 1      17    127       17_전년_영업_%↑_%↓
# 2      19    123       19_특징_종목_클릭_상승
# 3      22    119      22_뉴스_cj_특징_카카오
# 4      36     95     36_이해진_총수_대표_김상헌
# 5      27     93   27_스타트업_로봇_클라우드_투자
# 6      21     88      21_ir_네이버_종목_​"
# 7      26     82      26_규제_주가_급락_카카오
# 8       6     73    6_100_10_1000_500
# 9      13     62      13_60_매출_돌파_600
# 10     30     56     30_카카오_클레이_링크_연임
# 11     15     53       15_분기_영업_매출_"-
# 12      4     52      4_50_5000_매장_윈도
# 13     25     46     25_카카오_규제_이해진_아도
# 14      1     42        1_매출_시대_영업_연속
# 15     37     40     37_etf_금융_링크_하이브
# 16     28     37    28_스마트_공정위_스토어_근거
# 17     32     34      32_목표_↑"-_본격_sk
# 19      8     30  8_8000_파이낸셜_48_1283
# 18      9     30       9_다시_탈환_인터넷_솔솔
# 20     24     25       24_삼성_↑-_기업_사상
# 21      0     23      0_cj_동맹_맞교환_콘텐츠
# 22     29     22     29_카카오_나란히_vs_시선
# 23      5     21      5_20_주년_2000_조성
# ...

# %%
print('각 문서의 토픽 번호 리스트 :',len(topics))
print('첫번째 문서의 토픽 번호 :', topics[0])
# Out:
# 각 문서의 토픽 번호 리스트 : 2358
# 첫번째 문서의 토픽 번호 : -1

# %%
model.get_topic_info()['Count'].sum()
# Out:
# 2358

# %%
model.get_topic(5)
# Out:
# [('20', 0.25454070931008993),
#  ('주년', 0.08224432107989574),
#  ('2000', 0.07037489327872365),
#  ('조성', 0.06836982615416247),
#  ('편지', 0.0627923261310319),
#  ('여러분', 0.0627923261310319),
#  ('%↓', 0.05925833559112842),
#  ('대비', 0.05492917682914422),
#  ('전년', 0.05232118141976309),
#  ('연간', 0.05227501245143399)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topics, probs = model.transform([new_doc])
print('예측한 토픽 번호 :', topics)
# Out:
# 예측한 토픽 번호 : [-1]

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
