# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/TIL/blob/master/0104_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="body_mass_g", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="species", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="species", style="species", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="species", style="island", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="species", col="island", data=penguins);

# %%
sns.set(style="whitegrid")

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm", hue="species", col="island", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue="body_mass_g", size="body_mass_g", data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g", 
            hue="body_mass_g", size="body_mass_g",  sizes=(30, 100), data=penguins);

# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By


driver = webdriver.Chrome()
driver.get('https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000158639&dispCatNo=1000001000200010009&trackingCd=Result_1')
driver.implicitly_wait(10)
print(driver.find_element_by_css_selector("div .txt_inner").text)
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_1420/3012456387.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   print(driver.find_element_by_css_selector("div .txt_inner").text)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1420/3012456387.py in <module>
#       7 driver.get('https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000158639&dispCatNo=1000001000200010009&trackingCd=Result_1')
#       8 driver.implicitly_wait(10)
# ----> 9 print(driver.find_element_by_css_selector("div .txt_inner").text)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     806             stacklevel=2,
#     807         )
# --> 808         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     809
# ...

# %%
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(30)
driver.get('https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000158639&dispCatNo=1000001000200010009&trackingCd=Result_1')
print(driver.find_element_by_css_selector("div.txt_inner").text)
# Out:
# C:\Users\student\AppData\Local\Temp/ipykernel_1420/3714714243.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# C:\Users\student\AppData\Local\Temp/ipykernel_1420/3714714243.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   print(driver.find_element_by_css_selector("div.txt_inner").text)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1420/3714714243.py in <module>
#       5 driver.implicitly_wait(30)
#       6 driver.get('https://www.oliveyoung.co.kr/store/goods/getGoodsDetail.do?goodsNo=A000000158639&dispCatNo=1000001000200010009&trackingCd=Result_1')
# ----> 7 print(driver.find_element_by_css_selector("div.txt_inner").text)
#
# ...
