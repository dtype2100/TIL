# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/TIL/blob/master/data_vis_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finance-datareader

# %%
pip install plotly

# %%
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np
import datetime

import plotly.figure_factory as pff
import plotly.graph_objects as go
import plotly.express as px
import plotly.figure_factory as ff
import plotly.io as pio
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import FinanceDataReader as fdr

# %%
key_df = pd.read_excel('/content/drive/MyDrive/Final_project/data_sum/네이버_카카오_5%이상 등락 이벤트/네이버_5%이상_등락.xlsx')
naver_df = fdr.DataReader('035420', '20170101', '20220430')
naver_df['Date'] = naver_df.index
naver_df = naver_df.rename(columns = {'Date':'date'}) 
df = pd.merge(key_df, naver_df, how='inner', on='date')

# %%
df
# Out:
#     Unnamed: 0       date company  rate  \
# 0            0 2017-01-04   NAVER   5.6
# 1            1 2017-03-02   NAVER   5.0
# 2            2 2017-03-21   NAVER   6.5
# 3            3 2017-04-11   NAVER  -5.9
# 4            4 2017-05-11   NAVER   5.1
# 5            5 2017-06-09   NAVER   7.9
# 6            6 2017-06-12   NAVER  -6.8
# 7            7 2017-10-18   NAVER   6.1
# 8            8 2018-10-25   NAVER  -6.3
# 9            9 2018-10-26   NAVER  -5.0
# 10          10 2018-11-26   NAVER   8.8
# 11          11 2019-07-25   NAVER   8.5
# 12          12 2019-07-26   NAVER   5.2
# 13          13 2019-10-31   NAVER   6.1
# 14          14 2019-11-14   NAVER  13.9
# 15          15 2020-03-09   NAVER  -6.4
# 16          16 2020-03-20   NAVER   6.9
# 17          17 2020-03-24   NAVER   9.1
# 18          18 2020-03-27   NAVER   7.5
# 19          19 2020-04-02   NAVER   6.4
# 20          20 2020-04-17   NAVER   5.0
# 21          21 2020-05-06   NAVER   6.5
# ...

# %%
fig2 = make_subplots(specs=[[{"secondary_y": True}]])
fig2.add_trace(go.Scatter(x=df.index,y=df['Close'],name='Price'),secondary_y=False)
fig2.add_trace(go.Bar(x=df.index,y=df['Volume'],name='Volume'),secondary_y=True)
fig2.update_yaxes(range=[0,10000000],secondary_y=True)
fig2.update_yaxes(visible=False, secondary_y=True)

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = make_subplots(specs=[[{"secondary_y": True}]])
fig3.add_trace(go.Candlestick(x=df.index,
                              open=df['Open'],
                              high=df['High'],
                              low=df['Low'],
                              close=df['Close'],
                              increasing_line_color = 'red',
                              decreasing_line_color = 'blue'
                              ))
fig3.add_trace(go.Bar(x=df.index, y=df['Volume'], name='Volume'),secondary_y=True)
fig3.update_layout(xaxis_rangeslider_visible=False)
fig3.update_yaxes(range=[0,10000000],secondary_y=True)
fig3.update_yaxes(visible=False, secondary_y=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3.add_trace(go.Scatter(x=df.index,y=df['Close'].rolling(window=5).mean(),marker_color='green',name='5 Day MA'))
fig3.add_trace(go.Scatter(x=df.index,y=df['Close'].rolling(window=20).mean(),marker_color='red',name='20 Day MA'))
fig3.add_trace(go.Scatter(x=df.index,y=df['Close'].rolling(window=60).mean(),marker_color='orange',name='60 Day MA'))
fig3.add_trace(go.Scatter(x=df.index,y=df['Close'].rolling(window=120).mean(),marker_color='purple',name='120 Day MA'))
fig3.add_trace(go.Bar(x=df.index, y=df['Volume'], name='Volume'),secondary_y=True)
fig3.update_layout(title={'text':'LGU', 'x':0.5})
fig3.update_yaxes(range=[0,1000000000],secondary_y=True)
fig3.update_yaxes(visible=False, secondary_y=True)
fig3.update_layout(xaxis_rangeslider_visible=False)  #hide range slider
fig3.update_yaxes(range=[0,10000000],secondary_y=True)
fig3.update_yaxes(visible=False, secondary_y=True)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df , x='date', y='Close', hover_data=['Open', 'High', 'Low', 'Volume', 'top_keywords', 'rate', 'max_sum_sims'],  color='top_keywords')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df , x='date', y='Close', hover_data=['Open', 'High', 'Low', 'Volume', 'top_keywords', 'rate', 'max_sum_sims'], color='top_keywords')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df , x='date', y='Close', hover_data=['Open', 'High', 'Low', 'Volume', 'top_keywords', 'rate', 'max_sum_sims'], markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df , x='date', y='Close', hover_data=['Open', 'High', 'Low', 'Volume', 'top_keywords', 'rate', 'max_sum_sims'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x=df['date'], y=df['Close'], 
                 color="top_keywords",
                 size='Volume', 
                 hover_data=['Open', 'High', 'Low', 'Volume', 'rate', 'max_sum_sims'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df, x=df.index, y="Volume", hover_data=['Open', 'High', 'Low', 'Close', 'rate', 'top_keywords', 'max_sum_sims'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
