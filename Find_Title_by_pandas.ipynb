# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/TIL/blob/master/Find_Title_by_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_excel('/네이버 증권 뉴스_20170101-20220506.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#              뉴스 식별자        일자    언론사              기고자  \
# 0      2.100801e+06  20170101  아시아경제              박나영
# 1      7.100501e+06  20170101   전자신문              오대석
# 2      2.100311e+06  20170101   서울경제       유주희,김연하 기자
# 3      2.100101e+06  20170101   매일경제          문일호,채종원
# 4      1.500901e+06  20170101   울산매일           김준형 기자
# ...             ...       ...    ...              ...
# 17578  2.100101e+06  20220506   매일경제          강우석,강인선
# 17579  2.100101e+06  20220506   매일경제  안병준,김유신,신혜림,차창희
# 17580  1.101101e+06  20220506   한국일보              조아름
# 17581  8.100401e+06  20220506    YTN              박병한
# 17582  2.100311e+06  20220506   서울경제           김성태 기자
#
#                                                       제목    통합 분류1  \
# 0                        [클릭 e종목]네이버, 쇼핑 광고 성장 목표가 100만원  경제>증권_증시
# 1                    한성숙의 네이버, 임지훈의 카카오 정유년 새로운 성장기회 잡는다  경제>증권_증시
# 2       [증권사 10곳 신년 유망주] 업황 개선 신사업 본격화...삼성전자 엔씨소프트 '강추'  경제>증권_증시
# ...

# %% [markdown]
# # 원하는 키워드가 포함된 뉴스 제목 찾기

# %%
title_df = df[df['제목'].str.contains('네이버')]

# %%
title_df
# Out:
#              뉴스 식별자        일자    언론사       기고자  \
# 0      2.100801e+06  20170101  아시아경제       박나영
# 1      7.100501e+06  20170101   전자신문       오대석
# 5      1.101101e+06  20170101   한국일보       김동욱
# 21     2.100201e+06  20170103  머니투데이       이해인
# 40     2.100801e+06  20170104  아시아경제       권해영
# ...             ...       ...    ...       ...
# 17554  2.100601e+06  20220506   한국경제       차은지
# 17555  2.100201e+06  20220506  머니투데이    홍순빈|기자
# 17557  8.100201e+06  20220506    MBC  김민재/삼성증권
# 17566  2.100101e+06  20220506   매일경제       이병권
# 17571  1.101001e+06  20220506    한겨레    조계완 기자
#
#                                                   제목    통합 분류1  \
# 0                    [클릭 e종목]네이버, 쇼핑 광고 성장 목표가 100만원  경제>증권_증시
# 1                한성숙의 네이버, 임지훈의 카카오 정유년 새로운 성장기회 잡는다  경제>증권_증시
# 5                   코스피 시총 10위권의 변화, 네이버ㆍSK하이닉스 ‘점프’  경제>산업_기업
# 21                    '벤처 큰손'으로 뜨는 네이버 7000억 투자 '시동'  경제>증권_증시
# 40                    [특징주]네이버, 4Q 실적 컨센서스 부합 전망에 강세  경제>증권_증시
# ...

# %%
title_df.reset_index(drop=True, inplace=True)

# %%
title_df
# Out:
#             뉴스 식별자        일자    언론사       기고자  \
# 0     2.100801e+06  20170101  아시아경제       박나영
# 1     7.100501e+06  20170101   전자신문       오대석
# 2     1.101101e+06  20170101   한국일보       김동욱
# 3     2.100201e+06  20170103  머니투데이       이해인
# 4     2.100801e+06  20170104  아시아경제       권해영
# ...            ...       ...    ...       ...
# 2976  2.100601e+06  20220506   한국경제       차은지
# 2977  2.100201e+06  20220506  머니투데이    홍순빈|기자
# 2978  8.100201e+06  20220506    MBC  김민재/삼성증권
# 2979  2.100101e+06  20220506   매일경제       이병권
# 2980  1.101001e+06  20220506    한겨레    조계완 기자
#
#                                                  제목    통합 분류1          통합 분류2  \
# 0                   [클릭 e종목]네이버, 쇼핑 광고 성장 목표가 100만원  경제>증권_증시           경제>유통
# 1               한성숙의 네이버, 임지훈의 카카오 정유년 새로운 성장기회 잡는다  경제>증권_증시        경제>산업_기업
# 2                  코스피 시총 10위권의 변화, 네이버ㆍSK하이닉스 ‘점프’  경제>산업_기업        경제>증권_증시
# 3                    '벤처 큰손'으로 뜨는 네이버 7000억 투자 '시동'  경제>증권_증시          경제>반도체
# ...

# %%
title_df.to_excel('Big_Naver_title_only.xlsx')
