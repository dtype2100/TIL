# %%
import requests
from bs4 import BeautifulSoup

# %%
import json

# %%
url = "https://www.musinsa.com/category/001"
resp = requests.get(url)
html = BeautifulSoup(resp.text, 'html.parser')
lis = html.select("#searchList > li")
lis
# Out:
# [<li class="li_box" data-no="1783595">
#  <div class="icon_new">SALE 35%</div>
#  <div class="box-icon-right">
#  <span class="icon-reverse label-campaign05">시즌오프</span>
#  </div>
#  <div class="icon_group">
#  <ul>
#  <li class="icon_man sight_out" title="남성">남성</li>
#  </ul>
#  </div>
#  <div class="li_inner">
#  <div class="list_img">
#  <a class="img-block" href="https://store.musinsa.com/app/goods/1783595" name="goods_link" title="Half  Zip-Up M-Logo Sweat  (JM5TSU838MW)">
#  <img alt="지프(JEEP) Half  Zip-Up M-Logo Sweat  (JM5TSU838MW)" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210208/1783595/1783595_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png">
#  </img></a>
#  </div>
#  <div class="article_info">
#  <p class="item_title"><a href="https://www.musinsa.com/brands/jeep">지프</a></p>
#  <p class="list_info">
#  <a href="https://store.musinsa.com/app/goods/1783595" name="goods_link" title="Half  Zip-Up M-Logo Sweat  (JM5TSU838MW)">
# ...

# %%
for li in lis:
    print("브랜드 : {}".format(li.select_one(".item_title").text.strip()))
    print("제품명 : {}".format(li.select_one(".list_info").text.strip()))
    print("가격 : {}".format(li.select_one(".price").text.split( )[-1].strip()))
    print()
# Out:
# 브랜드 : 지프
# 제품명 : Half  Zip-Up M-Logo Sweat  (JM5TSU838MW)
# 가격 : 44,850원
#
# 브랜드 : 지프
# 제품명 : Half  Zip-Up M-Logo Sweat  (JM5TSU838NA)
# 가격 : 44,850원
#
# 브랜드 : 지프
# 제품명 : Half  Zip-Up M-Logo Sweat  (JM5TSU838DG)
# 가격 : 44,850원
#
# 브랜드 : 무신사 스탠다드
# 제품명 : 레이어드 크루 넥 반팔 티셔츠_긴 기장 [화이트]
# 가격 : 12,490원
#
# 브랜드 : 지프
# 제품명 : Half  Zip-Up M-Logo Sweat  (JM5TSU838OB)
# 가격 : 44,850원
#
# 브랜드 : 드로우핏
# 제품명 : [드로우핏X깡스타일리스트] 모크넥 니트 티셔츠 SET
# 가격 : 43,900원
#
# 브랜드 : 그루브라임
# 제품명 : [오늘만이가격] [패키지] (기모) NYC LOCATION SWEATSHIRT [LRPWCTM304M]
# 가격 : 42,000원
#
# 브랜드 : 지오다노
# 제품명 : 021541 레이어드 반팔 티셔츠(2pck)
# 가격 : 19,000원
#
# 브랜드 : 게인스보로
# 제품명 : 로고 아노락 풀오버 하프집업 네이비
# 가격 : 58,500원
#
# 브랜드 : 커버낫
# 제품명 : 럭비 맨투맨 네이비
# 가격 : 39,500원
#
# 브랜드 : 드로우핏
# 제품명 : [드로우핏X깡스타일리스트] 터틀넥 니트 티셔츠 SET
# 가격 : 43,900원
#
# 브랜드 : 게인스보로
# 제품명 : 로고 아노락 풀오버 하프집업 블랙
# 가격 : 58,500원
#
# 브랜드 : 예스아이씨
# 제품명 : Arch Logo Hoodie Navy
# 가격 : 58,800원
#
# 브랜드 : 체이스컬트
# 제품명 : 남성 오버핏 반집업 기모 맨투맨-AFAK5138D0N
# 가격 : 29,900원
#
# 브랜드 : 챔피온
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome('./chromedriver')
driver.get('https://www.musinsa.com/category/001')
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_19240/1874858782.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')

# %%
driver = webdriver.Chrome('./chromedriver', chrome_options=options)
driver.get('https://www.musinsa.com/category/001')
driver.implicitly_wait(2)
print(driver.find_element_by_css_selector("#item_title")
print(driver.find_element_by_css_selector("#item_info")
print(driver.find_element_by_css_selector("#price")
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_19240/3911046030.py", line 5
#     print(driver.find_element_by_css_selector("#item_info")
#     ^
# SyntaxError: invalid syntax
