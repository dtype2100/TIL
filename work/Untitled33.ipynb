# %%
import requests

# %%
URL = "https://scrapying-study.firebaseapp.com/01/"

# %%
response = requests.get(URL)

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<title>크롤링 연습사이트 01</title>\n</head>\n<body>\n<h1>저의 첫 웹사이트 오신것을 환영합니다.</h1>\n<h1 title="welcome">인사이트캠퍼스.</h1>\n<h2>이곳은 크롤링 연습을 위한 웹사이트입니다.</h2>\n<table border="1">\n    <thead>\n      <tr>\n      \t<th class="tablehead">이름</th>\n        <th class="tablehead">나이</th>\n      </tr>\n    </thead>\n    <tbody>\n      <tr>\n          <td>이몽룡</td>\n          <td>34</td>\n      </tr>\n      <tr>\n          <td>홍길동</td>\n          <td>23</td>\n      </tr>\n     </tbody>\n</table>\n<p id="hello">\n    이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.\n</p>\n<p id="cook">\n    전통적인 요리법이나 양식은 상당한 차이가 있지만, 이탈리아 요리는 다른 국가의 요리 문화에서 다양한 영감을 줄 만큼 다양하고 혁신적인 것으로 평가되고 있다. 각 지방마다 고유의 특색이 있어 그 양식도 다양하지만 크게 북부와 남부로 나눌 수 있다. 다른 나라와 국경을 맞대고 있던 북부 지방은 산업화되어 경제적으로 풍족하고 농업이 발달해 쌀이 풍부해 유제품이 다양한 반면 경제적으로 침체되었던 남부 지방은 올리브와 토마토, 모차렐라 치즈가 유명하고 특별히 해산물을 활용한 요리가 많다. 식재료와 치즈 등의 차이는 파스타의 종류와 소스와 
# ...

# %%
headers = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"}
url = "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=104&oid=003&aid=0010912308"

# %%
response = requests.get(url, headers=headers)

# %%
response.text
# Out:
# '<!DOCTYPE HTML> \r\n<html lang="ko"> \r\n<head>\r\n<meta charset="euc-kr">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="referrer" contents="always">\r\n<meta name="viewport" content="width=1106" />\r\n<title>미 CDC 코로나 감염 격리기간 10일에서 5일로 단축 : 네이버 뉴스</title>\r\n\n\n\t\n\t\n\t\t\n\t\n\n\n\t\n\t\n\t\n\t\t\n\t\t\n\t\t\n\t\n\n<meta property="me2:post_tag"\t\tcontent="뉴시스 : 네이버뉴스"/>\n<meta property="me2:category1"\t\tcontent="뉴시스"/>\n<meta property="me2:category2"\t\tcontent="세계"/>\n<meta property="me2:image"\t\t\tcontent="https://imgnews.pstatic.net/image/003/2021/12/28/NISI20211223_0000898644_web_20211223054837_20211228093310440.jpg"/>\n\n<meta property="og:title"\t\t\tcontent="미 CDC 코로나 감염 격리기간 10일에서 5일로 단축"/>\n<meta property="og:type"\t\t\tcontent="article"/>\n<meta property="og:url"\t\t\t\tcontent="https://news.naver.com/main/read.naver?mode=LSD&mid=sec&oid=003&aid=0010912308&sid1=001"/>\n<meta property="og:image"\t\t\tcontent="https://imgnews.pstatic.net/ima
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://scrapying-study.firebaseapp.com/01/'

# %%
response = requests.get(URL)

# %%
pip installbeautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "installbeautifulsoup4"

# %%
URL='https://scrapying-study.firebaseapp.com/01/'
response=requests.get(URL)
soup=BeautifulSoup(response.text,"html.parser")
result=soup.find("title")
print(result)
print(result.text)
# Out:
# <title>크롤링 연습사이트 01</title>
# 크롤링 연습사이트 01

# %%
result.text
# Out:
# '크롤링 연습사이트 01'

# %%
URL='https://scrapying-study.firebaseapp.com/01/'

# %%
response=requests.get(URL)

# %%
soup=BeautifulSoup(response.text,"html.parser")

# %%
result=soup.find("title")

# %%
print(result)
print(result.text)
# Out:
# <title>크롤링 연습사이트 01</title>
# 크롤링 연습사이트 01

# %%
soup.find("p")
# Out:
# <p id="hello">
#     이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
# </p>

# %%
soup.find_all("p", limit=2)
# Out:
# [<p id="hello">
#      이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
#  </p>,
#  <p id="cook">
#      전통적인 요리법이나 양식은 상당한 차이가 있지만, 이탈리아 요리는 다른 국가의 요리 문화에서 다양한 영감을 줄 만큼 다양하고 혁신적인 것으로 평가되고 있다. 각 지방마다 고유의 특색이 있어 그 양식도 다양하지만 크게 북부와 남부로 나눌 수 있다. 다른 나라와 국경을 맞대고 있던 북부 지방은 산업화되어 경제적으로 풍족하고 농업이 발달해 쌀이 풍부해 유제품이 다양한 반면 경제적으로 침체되었던 남부 지방은 올리브와 토마토, 모차렐라 치즈가 유명하고 특별히 해산물을 활용한 요리가 많다. 식재료와 치즈 등의 차이는 파스타의 종류와 소스와 수프 등도 다름을 의미한다.
#  </p>]

# %%
soup.find("th","tablehead")
# Out:
# <th class="tablehead">이름</th>

# %%
soup.find("th", class_="tablehead")
# Out:
# <th class="tablehead">이름</th>

# %%
soup.find("th", attrs={class:"tablehead"})
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_12580/1875390569.py", line 1
#     soup.find("th", attrs={class:"tablehead"})
#                            ^
# SyntaxError: invalid syntax

# %%
soup.find("h1", attrs={"title":"welcome"})

# %%
soup.find("h3", class_="tts_head")

# %%
soup.find(id="hello")

# %%
soup.text

# %%
soup

# %%
tbody = result.find("tbody")

# %%
import requests

# %%
URL = "https://scrapying-study.firebaseapp.com/01/"

# %%
response=requests.get(URL)

# %%
print(response.status_code)

# %%
print(response.text)

# %%
response=requests.get("https://scrapying-study.firebaseapp.com/01/")

# %%
result=soup.find("table")
result2=result.find("tbody")

# %%
print(result.text)

# %%
results1 = soup.find("a")

# %%
print(results1.text)

# %%
print(soup.a.string)

# %%
dic={}
dic2={}
th=soup.find_all("th")
td=soup.find_all("td")

for i in range(2):
    dic[th[i].text]=td[i].text

for j in range(2):
    dic2[th[j].text]=td[j+2].text

lst=[]
lst.append(dic)
lst.append(dic2)
lst

# %%
URL1 = "https://scrapying-study.firebaseapp.com/01/01.html"
URL2 = "https://scrapying-study.firebaseapp.com/01/02.html"
URL3 = "https://scrapying-study.firebaseapp.com/01/03.html"
URL4 = "https://scrapying-study.firebaseapp.com/01/04.html"

# %%
URL1 = requests.get("https://scrapying-study.firebaseapp.com/01/01.html")
URL2 = requests.get("https://scrapying-study.firebaseapp.com/01/02.html")
URL3 = requests.get("https://scrapying-study.firebaseapp.com/01/03.html")
URL4 = requests.get("https://scrapying-study.firebaseapp.com/01/04.html")

URL1 = soup.find("title")
URL2 = soup.find("title")
URL3 = soup.find("title")
URL4 = soup.find("title")

print(URL1)
print(URL2)
print(URL3)
print(URL4)

# %%
url = "https://scrapying-study.firebaseapp.com/01/"

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")
soup.find(id="cook").text.strip()

# %%
ths = soup.find_all("th")
print(ths[0].text)

# %%
th_list = [e.text for e in ths]
th_list

# %%
users = []

trs = soup.find("tbody").find_all("tr")
for tr in trs:
    temp = {}
    tds = tr.find_all("td")
    for i, td in enumerate(tds):
        temp[th_list[i]] = td.text
        
    users.append(temp)
    
print(users)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12580/2236803203.py in <module>
#       6     tds = tr.find_all("td")
#       7     for i, td in enumerate(tds):
# ----> 8         temp[th_list[i]] = td.text
#       9
#      10     users.append(temp)
#
# NameError: name 'th_list' is not defined

# %%
anchers = soup.find_all('a')
for anchers in anchers: 
    print(anchers.attrs['href'])
# Out:
# https://finance.naver.com/item/main.nhn?code=004770
# https://finance.naver.com/item/main.nhn?code=005930
# https://finance.naver.com/item/main.nhn?code=053800
# https://finance.naver.com/item/main.nhn?code=032500
# https://finance.naver.com/item/main.nhn?code=062970
# https://finance.naver.com/item/main.nhn?code=033780
# https://finance.naver.com/item/main.nhn?code=005935
# https://finance.naver.com/item/main.nhn?code=009190
# https://finance.naver.com/item/main.nhn?code=000660
# https://finance.naver.com/item/main.nhn?code=017670
# https://finance.naver.com/world/sise.nhn?symbol=DJI@DJI&fdtc=0
# https://finance.naver.com/world/sise.nhn?symbol=NAS@IXIC&fdtc=0
# https://finance.naver.com/world/sise.nhn?symbol=HSI@HSCE&fdtc=0
# https://finance.naver.com/world/sise.nhn?symbol=SHS@000001&fdtc=0
# https://finance.naver.com/world/sise.nhn?symbol=NII@NI225&fdtc=0
# #
# #
# #
# #
# #

# %%
anchers = soup.find_all('a')
for anchers in anchers: 
    link_url = url + anchers.attrs['href']
    resp = requests.get(link_url)
    html = BeautifulSoup(resp.text, "html.parser")
    print(html.find("p").text.strip())
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
URL = "https://scrapying-study.firebaseapp.com/03/"
resp = requests.get(URL)
html = BeautifulSoup(resp.text, "html.parser")
lis = html.select("ui#popularItem > li")

# %%
for li in lis:
    print(li.select_one("a").text)
    print(li.slecct_one("span".text))
