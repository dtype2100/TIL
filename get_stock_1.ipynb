# %% [markdown]
# <a href="https://colab.research.google.com/github/dtype2100/TIL/blob/master/get_stock_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finance-datareader
# Out:
# ...
#      |████████████████████████████████| 48 kB 2.5 MB/s
# ...

# %%
pip install pykrx
# Out:
# ...
#      |████████████████████████████████| 92 kB 420 kB/s
# ...
#      |████████████████████████████████| 51 kB 454 kB/s
# ...
#      |████████████████████████████████| 251 kB 39.1 MB/s
# ...

# %%
pip install pandas-datareader

# %%
pip install plotly # 차트 라이브러리

# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import plotly.graph_objects as go
import plotly.subplots as ms
import pandas_datareader as web

# kos_df = fdr.DataReader('KS11', '2020-03-06', '2020-03-20')
kos_df = fdr.DataReader('KS11', '2020-03-06', '2020-03-20')
# df = web.naver.NaverDailyReader('005930', start='20200101' , end='20201231').read()

df = kos_df.astype(int) # Object 데이터를 int로 변환

# %% [markdown]
# [미디엄 plotly](https://medium.com/search?q=plotly+)
#
# [BI 솔루션 비교](https://yannichoongs.tistory.com/280)
#
# [plotly 데모 갤러리](https://dash.gallery/Portal/)
#
# [plotly 메인](https://dash.plotly.com/introduction)
#
# [plotly 캔들차트 만들기1](https://youngwonhan-family.tistory.com/33)
#
# [plotly 깃헙 블로그에 올리기](https://dschloe.github.io/python/python_edu/03_datavisualisation/ch_plotly_html/)
#
# [plotly 웹 배포1](https://kibua20.tistory.com/216)
#
# [plotly 웹 배포2](https://wj-choi9473.github.io/%EC%A0%95%EB%A6%AC/plotly/)
#
# [plotly 웹 배포3](https://www.youtube.com/watch?v=hi-_5c0Xbik)
#
# [plotly 웹 배포4](https://plotly.com/python/getting-started/)
#
# [plotly 웹 배포5](https://mjs1995.tistory.com/184)
#
# [plotly 웹 배포6 (참고)](https://slowsteadystat.tistory.com/22)

# %%
# 캔들 차트 객체 생성
candle = go.Candlestick(
	x=df.index,
	open=df['Open'],
	high=df['High'],
	low=df['Low'],
	close=df['Close'],
    increasing_line_color = 'red', # 상승봉 스타일링
    decreasing_line_color = 'blue' # 하락봉 스타일링
)

# 바 차트(거래량) 객체 생성
volume_bar = go.Bar(x=df.index, y=df['Volume'])

# %%
fig = ms.make_subplots(rows=2, cols=1, shared_xaxes=True, vertical_spacing=0.02)

# %%
fig.add_trace(candle, row=1, col=1)
fig.add_trace(volume_bar, row=2, col=1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.update_layout(
    title='Kospi stock price',
    yaxis1_title='Stock Price',
    yaxis2_title='Volume',
    xaxis2_title='periods',
    xaxis1_rangeslider_visible=False,
    xaxis2_rangeslider_visible=True,    
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 한국거래소 전체 종목 가져오기

# %%
krx = fdr.StockListing('KRX')

# %%
krx
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 7902  000545   KOSPI            흥국화재우                       NaN
# 7903  003280   KOSPI             흥아해운                    해상 운송업
# 7904  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7905  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7906  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# ...

# %%
krx.groupby('Sector').count()
# Out:
#                      Symbol  Market  Name  Industry  ListingDate  SettleMonth  \
# Sector
# 1차 비철금속 제조업              18      18    18        17           18           18
# 1차 철강 제조업                57      57    57        57           57           57
# 가구 제조업                    8       8     8         8            8            8
# 가전제품 및 정보통신장비 소매업         2       2     2         2            2            2
# 가정용 기기 제조업                9       9     9         9            9            9
# ...                     ...     ...   ...       ...          ...          ...
# 해상 운송업                    5       5     5         5            5            5
# 해체, 선별 및 원료 재생업           1       1     1         1            1            1
# 화학섬유 제조업                  9       9     9         9            9            9
# 환경 정화 및 복원업               1       1     1         1            1            1
# 회사 본부 및 경영 컨설팅 서비스업      12      12    12        11           12           12
#
# ...

# %%
krx.groupby('Industry').count()
# Out:
#                                                 Symbol  Market  Name  Sector  \
# Industry
# -                                                    4       4     4       4
# 1) 마스크 도소매업 2) MB필터 생산 및 도소매업                        1       1     1       1
# 114전화번호안내, 고객센터                                      1       1     1       1
# 154kV, 345kV, 765kV 송전,변전,배전용 금구류, 섬유직기용 섹셔날 빔       1       1     1       1
# 1인미디어플랫폼                                             1       1     1       1
# ...                                                ...     ...   ...     ...
# 휴대폰윈도우                                               1       1     1       1
# 휴대폰인증서보관서비스(UBIKey)                                  1       1     1       1
# 휴대폰카메라모듈 등                                           1       1     1       1
# 히알루론산 관절염치료제, 히알루론산 더말필러                             1       1     1       1
# 히알루론산 필러(조직수복용생체재료), 피부과용 레이저 의료기기, 리프팅실 등           1       1     1       1
#
# ...

# %%
krx.groupby('Sector').count().sort_values('Symbol', ascending=False)[:30]
# Out:
#                                        Symbol  Market  Name  Industry  \
# Sector
# 소프트웨어 개발 및 공급업                            154     154   154       153
# 특수 목적용 기계 제조업                             146     146   146       146
# 전자부품 제조업                                  129     129   129       128
# 자동차 신품 부품 제조업                              96      96    96        96
# 의약품 제조업                                    95      95    95        95
# 기타 금융업                                     94      94    94        92
# 기타 화학제품 제조업                                93      93    93        93
# 금융 지원 서비스업                                 75      75    75        74
# 통신 및 방송 장비 제조업                             73      73    73        73
# 반도체 제조업                                    59      59    59        59
# 자연과학 및 공학 연구개발업                            59      59    59        59
# 1차 철강 제조업                                  57      57    57        57
# ...

# %%
sectors = dict(list(krx.groupby('Sector')))

print('count:', len(sectors))
list(sectors.keys())[:10]
# Out:
# count: 161
# ['1차 비철금속 제조업',
#  '1차 철강 제조업',
#  '가구 제조업',
#  '가전제품 및 정보통신장비 소매업',
#  '가정용 기기 제조업',
#  '가죽, 가방 및 유사제품 제조업',
#  '개인 및 가정용품 임대업',
#  '건물 건설업',
#  '건물설비 설치 공사업',
#  '건축기술, 엔지니어링 및 관련 기술 서비스업']

# %%
med_sec = sectors['1차 철강 제조업']

print('row count:', len(med_sec))
med_sec.head(10)
# Out:
# row count: 57
#       Symbol  Market      Name     Sector  \
# 96    069730   KOSPI     DSR제강  1차 철강 제조업
# 1452  016380   KOSPI    KG동부제철  1차 철강 제조업
# 1517  001940   KOSPI  KISCO홀딩스  1차 철강 제조업
# 1784  008260   KOSPI      NI스틸  1차 철강 제조업
# 1790  005490   KOSPI  POSCO홀딩스  1차 철강 제조업
# 1829  001770   KOSPI       SHD  1차 철강 제조업
# 1885  002710   KOSPI     TCC스틸  1차 철강 제조업
# 2098  039240  KOSDAQ      경남스틸  1차 철강 제조업
# 2117  002240   KOSPI      고려제강  1차 철강 제조업
# 2135  026910  KOSDAQ      광진실업  1차 철강 제조업
#
#                                                Industry ListingDate  \
# 96                    와이어로프,각종 경강선,철선제품,PC강선,아연도 강연선 제조  2003-01-28
# 1452  철강재(냉연강판,아연도강판,칼라강판,석도강판,선재류,강관,형강,봉강),비철금속 제조,도매  1986-02-03
# 1517                                               지주사업  1989-11-13
# 1784                                 스틸파이프,철강재임가공 제조,도매  1975-06-28
# 1790                           열연코일,냉연강판,후판,선재,스테인리스 제조  1988-06-10
# 1829                              석도강판,표면처리강판 제조,임가공,판매  1988-11-23
# ...

# %%
kos_df = fdr.DataReader('KS11', '2020-03-06', '2020-03-20')

# %%
kos_df
# Out:
#               Close     Open     High      Low        Volume  Change
# Date
# 2020-03-06  2040.22  2053.09  2062.57  2032.13  8.655900e+08 -0.0216
# 2020-03-09  1954.77  1981.02  1989.50  1946.90  6.668700e+08 -0.0419
# 2020-03-10  1962.93  1942.85  1968.17  1934.72  6.385600e+08  0.0042
# 2020-03-11  1908.27  1965.67  1967.70  1898.27  6.797200e+08 -0.0278
# 2020-03-12  1834.33  1887.97  1897.23  1808.56  8.503400e+08 -0.0387
# 2020-03-13  1771.44  1722.68  1809.31  1680.60  1.040000e+09 -0.0343
# 2020-03-16  1714.86  1805.43  1805.43  1714.38  6.820000e+08 -0.0319
# 2020-03-17  1672.44  1640.84  1722.97  1637.88  6.497800e+08 -0.0247
# 2020-03-18  1591.20  1686.12  1693.95  1591.12  7.280100e+08 -0.0486
# 2020-03-19  1457.64  1626.09  1626.09  1439.43  9.776700e+08 -0.0839
# 2020-03-20  1566.15  1498.49  1566.82  1466.48  8.170200e+08  0.0744

# %%
# 차트 설정
config = {'title': 'fdr.chart.config()',
          'width': 600,
          'height': 300,
          'volume': True}

# %%
fdr.chart.plot(kos_df) # 2020-03-06 ~ 2020-03-20
# Out:
#   <div class="bk-root" id="0afcd578-1f8d-41fd-92f7-7e455aca2c28" data-root-id="1153"></div>

# %%
kos_df1 = fdr.DataReader('KS11', '2020-03-20', '2021-01-08')

# %%
fdr.chart.plot(kos_df1)
# Out:
#   <div class="bk-root" id="e1fe3935-79df-4a03-9f4a-144086827c05" data-root-id="1497"></div>

# %%
kos_df2 = fdr.DataReader('KS11', '2020-10-30', '2021-01-08')

# %%
fdr.chart.plot(kos_df2)
# Out:
#   <div class="bk-root" id="afdd4939-013f-46f2-aebe-6dd8be07bb5a" data-root-id="1873"></div>

# %%
kos_df3 = fdr.DataReader('KS11', '2021-01-08', '2021-06-25')

# %%
fdr.chart.plot(kos_df3)
# Out:
#   <div class="bk-root" id="f99d1978-3d9f-40a1-bf7c-03f3a61c883a" data-root-id="2281"></div>

# %%
import pykrx
from pykrx import stock
from pykrx import bond

# %%
print(pykrx.__version__)
# Out:
# 1.0.32

# %% [markdown]
# # 코스피 데이터 수집

# %%
trade_df = stock.get_market_trading_value_by_date("20200306", '20200320', 'KOSPI')

# %%
trade_df
# Out:
#                     기관합계          기타법인             개인          외국인합계  전체
# 날짜
# 2020-03-06 -262500898512   34661648481   791505202117  -563665952086   0
# 2020-03-09  -46335792397   73876184949  1279952696242 -1307493088794   0
# 2020-03-10  611280071388   66955074619   311428799305  -989663945312   0
# 2020-03-11 -483799928785   78683693524  1088612946059  -683496710798   0
# 2020-03-12  275640021606   74589913403   538848382697  -889078317706   0
# 2020-03-13  584791380198  131791474110   446267566799 -1162850421107   0
# 2020-03-16 -346529372751   98858222674   926253868992  -678582718915   0
# 2020-03-17  350227711377   51833928820   600993518329 -1003055158526   0
# 2020-03-18 -514527352306  106684003901   913615877804  -505772529399   0
# 2020-03-19  289838355556   82993978828   242101933705  -614934268089   0
# 2020-03-20  311587391119   71262198003   200391678268  -583241267390   0

# %% [markdown]
# # 매도 포함 코스피 주가 데이터 수집

# %%
trade_df1 = stock.get_market_trading_value_by_date("20200306", '20200320', 'KOSPI', on='매도')

# %%
trade_df1
# Out:
#                      기관합계         기타법인             개인          외국인합계  \
# 날짜
# 2020-03-06  1836295005312  37752305882  3315855283853  2043635323889
# 2020-03-09  2121598083556  54343814434  3673302631942  2947699340511
# 2020-03-10  2003437625954  32844060444  3878646272964  3218765273057
# 2020-03-11  2255654548994  26269352825  3188838524965  3127334112779
# 2020-03-12  3084820165395  68642065418  4420444678297  3736046329787
# 2020-03-13  2529414192452  72908165090  6225865325424  4548750197310
# 2020-03-16  1952181022264  39959753356  4083183851761  2518508691421
# 2020-03-17  1857407091510  51932357659  4342859853791  3456877373474
# 2020-03-18  2206733313659  40800289057  4685141765427  2643712068244
# 2020-03-19  2541250801975  94635473890  5981956536561  3314649223459
# 2020-03-20  2254424165921  64047178217  5353204016409  2961294754151
#
#                         전체
# 날짜
# 2020-03-06   7233537918936
# 2020-03-09   8796943870443
# 2020-03-10   9133693232419
# ...

# %% [markdown]
# # etf, etn, elw 포함 코스피 데이터 수집

# %%
trade_df2 = stock.get_market_trading_value_by_date("20200306", '20200320', 'KOSPI', on='매도', etf=True, etn=True, elw=True)

# %%
trade_df2
# Out:
#                      기관합계          기타법인              개인          외국인합계  \
# 날짜
# 2020-03-06  2594208388841   71315992192   4533426197658  3082384555989
# 2020-03-09  3381303288386  100557628879   5220136688927  4149361385541
# 2020-03-10  3226655266587   89973202319   5719965313659  4583116793822
# 2020-03-11  3400654592304   75488624500   5044709666350  4857793987514
# 2020-03-12  4842473856730  138455423493   7245753572347  6842852808747
# 2020-03-13  4207199498560  178445881255   9680130357279  7771725156680
# 2020-03-16  3627889385549  120381983936   6918090299696  5024964379761
# 2020-03-17  3269319596340  171564025499   8356586178336  7286226758504
# 2020-03-18  3488720725085  109464164857   8181267308277  6073304092479
# 2020-03-19  4547403574560  321644733795  11749104225221  9858523923129
# 2020-03-20  3982965489576  184991168327   9932255158319  7840185701201
#
#                         전체
# 날짜
# 2020-03-06  10281335134680
# 2020-03-09  12851358991733
# ...

# %% [markdown]
# # detail 옵션 포함 코스피 데이터

# %%
trade_df3 = stock.get_market_trading_value_by_date("20200306", '20200320', 'KOSPI', on='매도', detail=True)

# %%
trade_df3
# Out:
#                      금융투자            보험            투신            사모  \
# 날짜
# 2020-03-06   869167318400   63986926690  139029054919   96914192907
# 2020-03-09   927331104014   66977462880  180167800509  146003807021
# 2020-03-10   598873612802   40107753176  258096042022  119864484485
# 2020-03-11   905939128026   69225306955  204787999048  148713343492
# 2020-03-12  1557253246204   70354691980  197573661180  100636835165
# 2020-03-13  1379084227503   67522978930  223274421151  119802475379
# 2020-03-16  1067943456402   56570654705  138383238827  120785831391
# 2020-03-17   616090694653   92097672807  163864132516  142883884678
# 2020-03-18   832054030858   84208555725  182094623792  122370764930
# 2020-03-19   890356952475  102261628157  314099980938  105700964018
# 2020-03-20   816986077724   58060140755  226352457174  107999997542
#
#                      은행         기타금융            연기금         기타법인  \
# 날짜
# 2020-03-06   4284542995   3148570725   659764398676  37752305882
# ...

# %% [markdown]
# # detail + etf, etn, elw 코스피 데이터

# %%
 trade_df4 = stock.get_market_trading_value_by_date("20200306", '20200320', 'KOSPI', on='매도', etf=True, etn=True, elw=True, detail=True)

# %%
trade_df4
# Out:
#                      금융투자            보험            투신            사모  \
# 날짜
# 2020-03-06  1420432397078  103195627471  245787030519  122449301567
# 2020-03-09  2058544219427   86902016952  233648405759  161908788226
# 2020-03-10  1638776727456   79845433651  288668249982  211986587340
# 2020-03-11  1925984343236  101152867590  231214769678  196221720312
# 2020-03-12  3127992488729   87484607610  276988043035  146109858505
# 2020-03-13  2766107828363  171189617423  299647173261  164446046279
# 2020-03-16  2441258473847   87469456835  370697314257  144498050306
# 2020-03-17  1511992034558  117708942447  522506647941  190941588903
# 2020-03-18  1928922937769  136390910725  233543456662  153577166415
# 2020-03-19  2296351427085  157448946237  755737231383  137441293298
# 2020-03-20  2407215380639  101234523635  253376349814  141967055857
#
#                      은행         기타금융            연기금          기타법인  \
# 날짜
# 2020-03-06  10260179445   3262296720   688821556041   71315992192
# ...

# %% [markdown]
# # 투자자별 거래실적 추이 (거래대금) (코스피)

# %%
trader_df1 = stock.get_market_trading_value_by_investor('2020-03-06', '2020-03-20', 'KOSPI')

# %%
trader_df1
# Out:
#                     매도               매수            순매수
# 투자자구분
# 금융투자    10461079849061    9475390827912  -985689021149
# 보험        771373772760     916914289557   145540516797
# 투신       2227723412076    1860590494714  -367132917362
# 사모       1331676581008    1087069669503  -244606911505
# 은행        216358566254     144743585909   -71614980345
# 기타금융      156738670290     143108426908   -13630243382
# 연기금 등    9478265165543   11785070308982  2306805143439
# 기관합계    24643216016992   25412887603485   769671586493
# 기타법인      584134816272    1456325137584   872190321312
# 개인      49149298741394   56489271211711  7339972470317
# 외국인     34399034597003   25393630930217 -9005403666786
# 기타외국인     118238091079     141807379743    23569288664
# 전체     108893922262740  108893922262740              0

# %% [markdown]
# # 투자자별 거래실적 추이 (거래대금) (코스피) + ETF, ETN, ELW

# %%
trader_df2 = stock.get_market_trading_value_by_investor('20200306', '20200320', 'KOSPI', etf=True, etn=True, elw=True)

# %%
trader_df2
# Out:
#                     매도               매수             순매수
# 투자자구분
# 금융투자    23523578258187   17044059321147  -6479518937040
# 보험       1230022950576    1500809981451    270787030875
# 투신       3711814672291    4773375841524   1061561169233
# 사모       1771547457008    1675450014238    -96097442770
# 은행        504169423094     579001339084     74831915990
# 기타금융      193242138884     195803310730      2561171846
# 연기금 등    9634418762478   11973638574872   2339219812394
# 기관합계    40568793662518   37742138383046  -2826655279472
# 기타법인     1562282829052    2573342449844   1011059620792
# 개인      82581424966069   92849138176696  10267713210627
# 외국인     67192421738778   58705482366027  -8486939372751
# 기타외국인     178017804589     212839625393     34821820804
# 전체     192082941001006  192082941001006               0

# %% [markdown]
# # 투자자별 거래실적 추이 (거래량) (코스피)

# %%
trader_df3 = stock.get_market_trading_volume_by_investor('20200306', '20200320', 'KOSPI')

# %%
trader_df3
# Out:
#                매도          매수        순매수
# 투자자구분
# 금융투자    289893353   285556862   -4336491
# 보험       33539998    26705601   -6834397
# 투신       80711774    47207538  -33504236
# 사모       52711781    34648661  -18063120
# 은행        6921509     3760378   -3161131
# 기타금융     14627870     8879596   -5748274
# 연기금 등   243442463   249704721    6262258
# 기관합계    721848748   656463357  -65385391
# 기타법인     38813110   104245688   65432578
# 개인     6287267588  6426708642  139441054
# 외국인    1527991424  1387048475 -140942949
# 기타외국인    14925152    16379860    1454708
# 전체     8590846022  8590846022          0

# %% [markdown]
# # 투자자별 순매수 상위종목(개인)

# %%
trader_df4 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '개인')

# %%
trader_df4
# Out:
#              종목명      매도거래량      매수거래량    순매수거래량         매도거래대금  \
# 티커
# 005930      삼성전자  145770875  216763851  70992976  7068219016200
# 005380       현대차    9826514   16095153   6268639   818728403800
# 000660    SK하이닉스   25757043   31333973   5576930  2029275680700
# 005935     삼성전자우   16748866   27641652  10892786   690616118450
# 051910      LG화학    3537166    4614097   1076931  1085995648500
# ...          ...        ...        ...       ...            ...
# 001740    SK네트웍스   17754835   11842001  -5912834    86512682525
# 251270       넷마블    2581747    1912416   -669331   234472217900
# 207940  삼성바이오로직스    2426466    2159898   -266568  1053693189000
# 068270      셀트리온   10613913    9879012   -734901  1721152846500
# 180640       한진칼   30386673   28270833  -2115840  1784755143400
#
#                 매수거래대금        순매수거래대금
# 티커
# 005930  10636654853750  3568435837550
# 005380   1361105719800   542377316000
# 000660   2500925275700   471649595000
# ...

# %% [markdown]
# # 투자자별 순매수 상위종목(외국인)

# %%
trader_df5 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '외국인')

# %%
trader_df5
# Out:
#              종목명      매도거래량     매수거래량    순매수거래량         매도거래대금         매수거래대금  \
# 티커
# 207940  삼성바이오로직스     606573    756710    150137   269369794500   334446843000
# 180640       한진칼    4219810   5029895    810085   237236452100   297131460500
# 251270       넷마블    1158182   1675954    517772   104382689000   151971304800
# 033780      KT&G    3473867   3953831    479964   269671471800   307696480000
# 034220   LG디스플레이   16872831  20174198   3301367   196071957030   228389892950
# ...          ...        ...       ...       ...            ...            ...
# 051910      LG화학    3580469   2497210  -1083259  1136817322000   793252556500
# 005935     삼성전자우   27184725  16315715 -10869010  1150899316480   679671975030
# 005380       현대차   12469829   6146361  -6323468  1105597327613   554640828713
# 000660    SK하이닉스   29625944  19988651  -9637293  2412194690956  1615890033056
# 005930      삼성전자  160405695  81945278 -78460417  8000552126254  4060547906504
#
#               순매수거래대금
# 티커
# ...

# %% [markdown]
# # 투자자별 순매수 상위종목(기타외국인)

# %%
trader_df6 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '기타외국인')

# %%
trader_df6
# Out:
#             종목명   매도거래량   매수거래량  순매수거래량       매도거래대금       매수거래대금     순매수거래대금
# 티커
# 005930     삼성전자  380552  564313  183761  18749967950  27944330100  9194362150
# 051910     LG화학    5008   13825    8817   1587476500   4420090500  2832614000
# 005935    삼성전자우   30469   82519   52050   1259690400   3494922250  2235231850
# 000660   SK하이닉스   77340  102994   25654   6387621400   8332196200  1944574800
# 005380      현대차   44510   63337   18827   3879452400   5617696900  1738244500
# ...         ...     ...     ...     ...          ...          ...         ...
# 003580  넥스트사이언스  119341   23136  -96205    743250420    139672870  -603577550
# 004970     신라교역   72905       0  -72905    630926370            0  -630926370
# 088980   맥쿼리인프라  104954   38336  -66618   1070220810    388314680  -681906130
# 003000     부광약품  183798  134564  -49234   3120391500   2252904600  -867486900
# 180640      한진칼   48524   31179  -17345   3068956900   1831932850 -1237024050
#
# [846 rows x 7 columns]

# %% [markdown]
# # 투자자별 순매수 상위종목(금융투자)

# %%
trader_df7 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '금융투자')

# %%
trader_df7
# Out:
#             종목명     매도거래량     매수거래량   순매수거래량         매도거래대금         매수거래대금  \
# 티커
# 068270     셀트리온   1350911   1519203   168292   227462218500   253056373500
# 036570    엔씨소프트    271038    305533    34495   167146212000   186764924000
# 011170    롯데케미칼    401733    446186    44453    66110059000    74146139500
# 042670  두산인프라코어   3799339   6417250  2617911    12891508115    20724338360
# 010780   아이에스동서    118668    398974   280306     2644819050     9143413600
# ...         ...       ...       ...      ...            ...            ...
# 005380      현대차   2855499   2483244  -372255   250566290600   221724453600
# 015760     한국전력   8849380   6706513 -2142867   178422964000   136180813300
# 005490    POSCO   1418928   1150252  -268676   238835555500   194534015000
# 000660   SK하이닉스   8464597   7434216 -1030381   690467207200   599834542800
# 005930     삼성전자  64242560  56172341 -8070219  3178736452200  2755367672200
#
#              순매수거래대금
# 티커
# 068270   25594155000
# ...

# %% [markdown]
# # 투자자별 순매수 상위종목(보험)

# %%
trader_df8 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '보험')

# %%
trader_df8
# Out:
#             종목명    매도거래량    매수거래량   순매수거래량       매도거래대금        매수거래대금  \
# 티커
# 000660   SK하이닉스   300664   791044   490380  23881772400   65053842100
# 005930     삼성전자  1741769  2379725   637956  83227491950  118980470600
# 035420    NAVER    62284   201897   139613   9885899000   32127163500
# 036570    엔씨소프트     7560    39695    32135   4584760000   23701973000
# 068270     셀트리온    31727   122874    91147   5241150500   20743991000
# ...         ...      ...      ...      ...          ...           ...
# 028050  삼성엔지니어링   686533    49774  -636759   7282853630     557700900
# 009540   한국조선해양   166572    51062  -115510  13887292500    4221014100
# 009150     삼성전기   168124    82735   -85389  18923435200    9175291600
# 010140    삼성중공업  2165053   129494 -2035559  10525776125     559758385
# 096770  SK이노베이션   213298    95920  -117378  17903126200    7295733600
#
#             순매수거래대금
# 티커
# 000660  41172069700
# 005930  35752978650
# 035420  22241264500
# 036570  19117213000
# ...

# %% [markdown]
# # 투자자별 순매수 상위종목(연기금)

# %%
trader_df9 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '연기금')

# %%
trader_df9
# Out:
#             종목명     매도거래량     매수거래량    순매수거래량         매도거래대금         매수거래대금  \
# 티커
# 005930     삼성전자  73639400  90588231  16948831  3643948677750  4480241147850
# 000660   SK하이닉스  10243482  14717000   4473518   822526964800  1182831546900
# 035420    NAVER    791406   1595053    803647   126326775000   253765236500
# 036570    엔씨소프트    145468    298170    152702    89285122000   179901442000
# 051900   LG생활건강     78828    144746     65918    92705283000   168701856000
# ...         ...       ...       ...       ...            ...            ...
# 000150       두산    513407     35818   -477589    20999180950     1564788050
# 034220  LG디스플레이   3925882   2118200  -1807682    44983110940    24617258170
# 180640      한진칼    385566     13567   -371999    21667748700      679873350
# 020150  일진머티리얼즈    782649    176854   -605795    28831639600     6489234650
# 010140    삼성중공업  10414854   3692058  -6722796    48628412910    17249327445
#
#              순매수거래대금
# 티커
# 005930  836292470100
# ...

# %% [markdown]
# # 투자자별 순매수 상위종목(기관합계)

# %%
trader_df10 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '기관합계')

# %%
trader_df10
# Out:
#             종목명      매도거래량      매수거래량    순매수거래량         매도거래대금         매수거래대금  \
# 티커
# 000660   SK하이닉스   21871888   25691908   3820020  1766665639900  2072570020400
# 005930     삼성전자  157202077  161465665   4263588  7757605757100  7968182610700
# 036570    엔씨소프트     470140     771552    301412   290068509000   467299862000
# 035420    NAVER    2417124    3351085    933961   389059624000   532786011000
# 068270     셀트리온    2104507    2820208    715701   352550914000   470040415000
# ...         ...        ...        ...       ...            ...            ...
# 009150     삼성전기    3932134    3563514   -368620   433835229000   383388397400
# 015760     한국전력   18234637   14954052  -3280585   365033000650   303399197150
# 010140    삼성중공업   22489942    9277068 -13212874   104958691240    42335353270
# 003490     대한항공    7485993    3649451  -3836542   141099419000    75928219350
# 034220  LG디스플레이   10952502    5209660  -5742842   127122659350    61011754420
#
#              순매수거래대금
# 티커
# ...

# %% [markdown]
# # 투자자별 순매수 상위종목(전체)

# %%
trader_df11 = stock.get_market_net_purchases_of_equities('20200306', '20200320', 'KOSPI', '전체')

# %%
trader_df11
# Out:
#             종목명      매도거래량      매수거래량  순매수거래량        매도거래대금        매수거래대금  \
# 티커
# 095570   AJ네트웍스    2567959    2567959       0    6877041750    6877041750
# 006840    AK홀딩스     619467     619467       0   10936877650   10936877650
# 027410      BGF    5134012    5134012       0   19130030860   19130030860
# 282330   BGF리테일     510344     510344       0   68924926500   68924926500
# 138930  BNK금융지주   23622314   23622314       0  108605584395  108605584395
# ...         ...        ...        ...     ...           ...           ...
# 069260      휴켐스    1510366    1510366       0   23237984400   23237984400
# 000540     흥국화재    1241117    1241117       0    2442457275    2442457275
# 000547  흥국화재2우B      40450      40450       0     637253250     637253250
# 000545    흥국화재우    1295579    1295579       0    6921549865    6921549865
# 003280     흥아해운  503646612  503646612       0  158620058606  158620058606
#
#         순매수거래대금
# 티커
# 095570        0
# 006840        0
# 027410        0
# ...

# %% [markdown]
# # 종목별 시가 총액 조회

# %%
stock_item = stock.get_market_cap('20200306')

# %%
stock_item
# Out:
#             종가             시가총액       거래량           거래대금       상장주식수
# 티커
# 005930   56500  337292714075000  18716656  1058857640100  5969782550
# 000660   92600   67413018999000   3281612   304717451900   728002365
# 005935   47450   39045973915000   3419692   163324626130   822886700
# 207940  491000   32487015000000     93421    45798291500    66165000
# 035420  179500   29584004402500    293897    52626855500   164813395
# ...        ...              ...       ...            ...         ...
# 001529   28450       2552590900      9304      271818950       89722
# 276240     469       2426793600         1            469     5174400
# 208890     990       2129311800         0              0     2150820
# 238500     440       2060153040     10016        4413520     4682166
# 267810    1315       2034305000       751        1122565     1547000
#
# [2476 rows x 5 columns]

# %% [markdown]
#  # 일자별 시가 총액 조회

# %%
stock_date = stock.get_market_cap("20200306", "20200320", "005930")

# %%
stock_date
# Out:
#                        시가총액       거래량           거래대금       상장주식수
# 날짜
# 2020-03-06  337292714075000  18716656  1058857640100  5969782550
# 2020-03-09  323562214210000  30261485  1642720550800  5969782550
# 2020-03-10  325950127230000  32106554  1744478326491  5969782550
# 2020-03-11  311025670855000  45707281  2425785996150  5969782550
# 2020-03-12  303264953540000  48149999  2436965909150  5969782550
# 2020-03-13  298190638372500  59462933  2902883152100  5969782550
# 2020-03-16  291922366695000  33339821  1657128732300  5969782550
# 2020-03-17  282370714615000  51218151  2453541661000  5969782550
# 2020-03-18  272222084280000  40152623  1896703404150  5969782550
# 2020-03-19  256402160522500  56925513  2502939391663  5969782550
# 2020-03-20  271028127770000  49730008  2221272156100  5969782550

# %% [markdown]
# # 티커별 외국인 보유량 및 외국인 한도소진률

# %%
tiker1 = stock.get_exhaustion_rates_of_foreign_investment('20200306')

# %%
tiker1
# Out:
#             상장주식수      보유수량        지분율       한도수량      한도소진률
# 티커
# 000020   27931470   1579092   5.648438   27931470   5.648438
# 000040   47361018  25984893  54.875000   47361018  54.875000
# 000050   27415270    492331   1.799805   27415270   1.799805
# 000060  113680000  14762151  12.992188  113680000  12.992188
# 000070    8564271    727584   8.500000    8564271   8.500000
# ...           ...       ...        ...        ...        ...
# 33637K    7366400    232150   3.150391    7366400   3.150391
# 33637L    1646050      1870   0.109985    1646050   0.109985
# 338100   18660000     79025   0.419922   18660000   0.419922
# 344820    8350210    860976  10.312500    8350210  10.312500
# 900140   51120439   1716979   3.359375   51120439   3.359375
#
# [916 rows x 5 columns]

# %%
tiker2 = stock.get_exhaustion_rates_of_foreign_investment('20200320')

# %%
tiker2
# Out:
#             상장주식수      보유수량        지분율       한도수량      한도소진률
# 티커
# 000020   27931470   1518678   5.441406   27931470   5.441406
# 000040   47361018  25639375  54.125000   47361018  54.125000
# 000050   27415270    488147   1.780273   27415270   1.780273
# 000060  113680000  14189259  12.476562  113680000  12.476562
# 000070    8564271    705219   8.226562    8564271   8.226562
# ...           ...       ...        ...        ...        ...
# 33637K    7366400    177079   2.400391    7366400   2.400391
# 33637L    1646050      1618   0.099976    1646050   0.099976
# 338100   18660000     74992   0.399902   18660000   0.399902
# 344820    8350210    912865  10.929688    8350210  10.929688
# 900140   51120439   1456881   2.849609   51120439   2.849609
#
# [916 rows x 5 columns]

# %% [markdown]
# # 티커별 외국인 보유량 및 외국인 한도소진률(코스피)

# %%
tiker3 = stock.get_exhaustion_rates_of_foreign_investment('20200306', 'KOSPI')

# %%
tiker3
# Out:
#             상장주식수      보유수량        지분율       한도수량      한도소진률
# 티커
# 000020   27931470   1579092   5.648438   27931470   5.648438
# 000040   47361018  25984893  54.875000   47361018  54.875000
# 000050   27415270    492331   1.799805   27415270   1.799805
# 000060  113680000  14762151  12.992188  113680000  12.992188
# 000070    8564271    727584   8.500000    8564271   8.500000
# ...           ...       ...        ...        ...        ...
# 33637K    7366400    232150   3.150391    7366400   3.150391
# 33637L    1646050      1870   0.109985    1646050   0.109985
# 338100   18660000     79025   0.419922   18660000   0.419922
# 344820    8350210    860976  10.312500    8350210  10.312500
# 900140   51120439   1716979   3.359375   51120439   3.359375
#
# [916 rows x 5 columns]

# %%
tiker4 = stock.get_exhaustion_rates_of_foreign_investment('20200320', 'KOSPI')

# %%
tiker4
# Out:
#             상장주식수      보유수량        지분율       한도수량      한도소진률
# 티커
# 000020   27931470   1518678   5.441406   27931470   5.441406
# 000040   47361018  25639375  54.125000   47361018  54.125000
# 000050   27415270    488147   1.780273   27415270   1.780273
# 000060  113680000  14189259  12.476562  113680000  12.476562
# 000070    8564271    705219   8.226562    8564271   8.226562
# ...           ...       ...        ...        ...        ...
# 33637K    7366400    177079   2.400391    7366400   2.400391
# 33637L    1646050      1618   0.099976    1646050   0.099976
# 338100   18660000     74992   0.399902   18660000   0.399902
# 344820    8350210    912865  10.929688    8350210  10.929688
# 900140   51120439   1456881   2.849609   51120439   2.849609
#
# [916 rows x 5 columns]

# %% [markdown]
# # 일자별 외국인 보유량 및 외국인 한도소진률

# %%
date_foreign = stock.get_exhaustion_rates_of_foreign_investment("20200306", "20200320", "005930")

# %%
date_foreign
# Out:
#                  상장주식수        보유수량       지분율        한도수량     한도소진률
# 날짜
# 2020-03-06  5969782550  3371029903  56.46875  5969782550  56.46875
# 2020-03-09  5969782550  3368279127  56.40625  5969782550  56.40625
# 2020-03-10  5969782550  3358278619  56.25000  5969782550  56.25000
# 2020-03-11  5969782550  3351584933  56.12500  5969782550  56.12500
# 2020-03-12  5969782550  3341401720  55.96875  5969782550  55.96875
# 2020-03-13  5969782550  3332243792  55.81250  5969782550  55.81250
# 2020-03-16  5969782550  3321589476  55.62500  5969782550  55.62500
# 2020-03-17  5969782550  3322755885  55.65625  5969782550  55.65625
# 2020-03-18  5969782550  3311728922  55.46875  5969782550  55.46875
# 2020-03-19  5969782550  3311183096  55.46875  5969782550  55.46875
# 2020-03-20  5969782550  3307989649  55.40625  5969782550  55.40625
